# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceViesAngel/GraceViesAngel/blob/main/Check_point_2_Grace_Vies_Angel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/AVD/student_spending (1) (1).csv')

# %% [markdown]
# # **DATA UNDERSTANDING**

# %% [markdown]
# # pemeriksaan struktur data

# %%
df
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %%
print('menampilkan beberapa row data')
df.head(10)
# Out:
# menampilkan beberapa row data
#    Unnamed: 0  age      gender year_in_school             major  \
# 0           0   19  Non-binary       Freshman        Psychology
# 1           1   24      Female         Junior         Economics
# 2           2   24  Non-binary         Junior         Economics
# 3           3   23      Female         Senior  Computer Science
# 4           4   20      Female         Senior  Computer Science
# 5           5   25  Non-binary      Sophomore  Computer Science
# 6           6   23      Female       Freshman       Engineering
# 7           7   23      Female         Junior         Economics
# 8           8   22  Non-binary         Senior  Computer Science
# 9           9   18      Female         Junior  Computer Science
#
#    monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0             958            270     5939      709   296             123
# 1            1006            875     4908      557   365              85
# ...

# %%
print('menampilkan 3 baris pertama pada data:')
df.head(3)
# Out:
# menampilkan 3 baris pertama pada data:
#    Unnamed: 0  age      gender year_in_school       major  monthly_income  \
# 0           0   19  Non-binary       Freshman  Psychology             958
# 1           1   24      Female         Junior   Economics            1006
# 2           2   24  Non-binary         Junior   Economics             734
#
#    financial_aid  tuition  housing  food  transportation  books_supplies  \
# 0            270     5939      709   296             123             188
# 1            875     4908      557   365              85             252
# 2            928     3051      666   220             137              99
#
#    entertainment  personal_care  technology  health_wellness  miscellaneous  \
# 0             41             78         134              127             72
# 1             74             92         226              129             68
# 2            130             23         239              112            133
#
# ...

# %%
print('menampilkan 6 baris terakhir pada data:')
df.tail(6)
# Out:
# menampilkan 6 baris terakhir pada data:
#      Unnamed: 0  age      gender year_in_school             major  \
# 994         994   22        Male         Senior        Psychology
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 994             764            286     5430      589   387              61
# 995            1346            520     3688      969   152             194
# 996            1407            560     3380      508   265              52
# 997             957            393     3497      723   339             139
# 998            1174            612     3649      543   237             123
# ...

# %%
print('menampilkan sedikit informasi tentang dataset:')
df.info()
# Out:
# menampilkan sedikit informasi tentang dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   age                       1000 non-null   int64
#  2   gender                    1000 non-null   object
#  3   year_in_school            1000 non-null   object
#  4   major                     1000 non-null   object
#  5   monthly_income            1000 non-null   int64
#  6   financial_aid             1000 non-null   int64
#  7   tuition                   1000 non-null   int64
#  8   housing                   1000 non-null   int64
#  9   food                      1000 non-null   int64
#  10  transportation            1000 non-null   int64
#  11  books_supplies            1000 non-null   int64
#  12  entertainment             1000 non-null   int64
# ...

# %%
print('menampilkan tipe data dari setiap kolom:')
print(df.dtypes)
# Out:
# menampilkan tipe data dari setiap kolom:
# Unnamed: 0                   int64
# age                          int64
# gender                      object
# year_in_school              object
# major                       object
# monthly_income               int64
# financial_aid                int64
# tuition                      int64
# housing                      int64
# food                         int64
# transportation               int64
# books_supplies               int64
# entertainment                int64
# personal_care                int64
# technology                   int64
# health_wellness              int64
# miscellaneous                int64
# preferred_payment_method    object
# dtype: object

# %%
print('menampilkan jumlah baris dan kolom pada dataset:')
print(df.shape)
# Out:
# menampilkan jumlah baris dan kolom pada dataset:
# (1000, 18)

# %% [markdown]
# # statistik deskriptif dan analisis korelasi

# %%
df
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %%
print('menampilkan statistik deskriptif dari dataset:')
print(df.describe())
# Out:
# menampilkan statistik deskriptif dari dataset:
#         Unnamed: 0          age  monthly_income  financial_aid      tuition  \
# count  1000.000000  1000.000000     1000.000000    1000.000000  1000.000000
# mean    499.500000    21.675000     1020.650000     504.771000  4520.395000
# std     288.819436     2.322664      293.841161     287.092575   860.657944
# min       0.000000    18.000000      501.000000       0.000000  3003.000000
# 25%     249.750000    20.000000      770.750000     261.000000  3779.750000
# 50%     499.500000    22.000000     1021.000000     513.000000  4547.500000
# 75%     749.250000    24.000000     1288.250000     751.500000  5285.000000
# max     999.000000    25.000000     1500.000000    1000.000000  6000.000000
#
#           housing         food  transportation  books_supplies  entertainment  \
# count  1000.00000  1000.000000      1000.00000     1000.000000    1000.000000
# mean    696.00600   252.642000       124.63700      174.761000      84.814000
# ...

# %%
kolom_unik = 'food'
if kolom_unik in df.columns:
  print(f'\nJumlah nilai unik dalam kolom {kolom_unik}:')
  print(df[kolom_unik].value_counts())
else:
  print(f'\nKolom {kolom_unik} tidak ditemukan dalam dataset.')

print('\nmenghitung rata-rata dari setiap kolom:')
print(df.mean(numeric_only=True))

print('\nmenghitung median dari setiap kolom:')
print(df.median(numeric_only=True))

print('\nmenghitung standar deviasi dari setiap kolom:')
print(df.std(numeric_only=True))

print('\nmenghitung korelasi antara setiap pasangan kolom:')
print(df.corr(numeric_only=True))
# Out:
# Jumlah nilai unik dalam kolom food:
# food
# 249    11
# 375    10
# 159     9
# 335     9
# 269     8
#        ..
# 351     1
# 117     1
# 379     1
# 211     1
# 244     1
# Name: count, Length: 290, dtype: int64
#
# menghitung rata-rata dari setiap kolom:
# Unnamed: 0          499.500
# age                  21.675
# monthly_income     1020.650
# financial_aid       504.771
# tuition            4520.395
# housing             696.006
# food                252.642
# transportation      124.637
# books_supplies      174.761
# entertainment        84.814
# personal_care        60.699
# technology          178.304
# health_wellness     114.310
# miscellaneous       108.910
# dtype: float64
#
# menghitung median dari setiap kolom:
# Unnamed: 0          499.5
# age                  22.0
# monthly_income     1021.0
# financial_aid       513.0
# tuition            4547.5
# housing             704.5
# food                255.0
# transportation      123.0
# books_supplies      175.0
# ...

# %% [markdown]
# # **DATA PREPARATION**

# %% [markdown]
# # Melihat Missing Values

# %% [markdown]
# tidak ada nilai yang hilang di dalam dataset "students spending habits

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Unnamed: 0                  0.0
# age                         0.0
# gender                      0.0
# year_in_school              0.0
# major                       0.0
# monthly_income              0.0
# financial_aid               0.0
# tuition                     0.0
# housing                     0.0
# food                        0.0
# transportation              0.0
# books_supplies              0.0
# entertainment               0.0
# personal_care               0.0
# technology                  0.0
# health_wellness             0.0
# miscellaneous               0.0
# preferred_payment_method    0.0
# dtype: float64

# %% [markdown]
# # Duplicated Values

# %% [markdown]
# tidak ada data yang duplikat pada dataset "student spending habits

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, age, gender, year_in_school, major, monthly_income, financial_aid, tuition, housing, food, transportation, books_supplies, entertainment, personal_care, technology, health_wellness, miscellaneous, preferred_payment_method]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %% [markdown]
# # Outliers

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom            Persentase Outliers
# Unnamed: 0                       0.0
# age                              0.0
# monthly_income                   0.0
# financial_aid                    0.0
# tuition                          0.0
# housing                          0.0
# food                             0.0
# transportation                   0.0
# books_supplies                   0.0
# entertainment                    0.0
# personal_care                    0.0
# technology                       0.0
# health_wellness                  0.0
# miscellaneous                    0.0

# %%
df
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %% [markdown]
# # Inconsistens Values

# %% [markdown]
# tidak ada nilai yang tidak konsisten di dalam dataset "student spending habits"

# %%
df
# Out:
#      Unnamed: 0  age      gender year_in_school             major  \
# 0             0   19  Non-binary       Freshman        Psychology
# 1             1   24      Female         Junior         Economics
# 2             2   24  Non-binary         Junior         Economics
# 3             3   23      Female         Senior  Computer Science
# 4             4   20      Female         Senior  Computer Science
# ..          ...  ...         ...            ...               ...
# 995         995   22      Female         Senior           Biology
# 996         996   19      Female         Senior           Biology
# 997         997   20        Male         Junior         Economics
# 998         998   22  Non-binary         Senior         Economics
# 999         999   24  Non-binary      Sophomore  Computer Science
#
#      monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0               958            270     5939      709   296             123
# ...

# %% [markdown]
# # Construct data

# %%
df['total_funds'] = df['monthly_income'] + df['financial_aid']
print(df.head())
# Out:
#    Unnamed: 0  age      gender year_in_school             major  \
# 0           0   19  Non-binary       Freshman        Psychology
# 1           1   24      Female         Junior         Economics
# 2           2   24  Non-binary         Junior         Economics
# 3           3   23      Female         Senior  Computer Science
# 4           4   20      Female         Senior  Computer Science
#
#    monthly_income  financial_aid  tuition  housing  food  transportation  \
# 0             958            270     5939      709   296             123
# 1            1006            875     4908      557   365              85
# 2             734            928     3051      666   220             137
# 3             617            265     4935      652   289             114
# 4             810            522     3887      825   372             168
#
#    books_supplies  entertainment  personal_care  technology  health_wellness  \
# ...

# %% [markdown]
# # Data reduction

# %%
df = df.drop('gender', axis=1)

# %%
df
# Out:
#      Unnamed: 0  age year_in_school             major  monthly_income  \
# 0             0   19       Freshman        Psychology             958
# 1             1   24         Junior         Economics            1006
# 2             2   24         Junior         Economics             734
# 3             3   23         Senior  Computer Science             617
# 4             4   20         Senior  Computer Science             810
# ..          ...  ...            ...               ...             ...
# 995         995   22         Senior           Biology            1346
# 996         996   19         Senior           Biology            1407
# 997         997   20         Junior         Economics             957
# 998         998   22         Senior         Economics            1174
# 999         999   24      Sophomore  Computer Science             541
#
#      financial_aid  tuition  housing  food  transportation  books_supplies  \
# ...
